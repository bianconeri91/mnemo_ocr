# %% [markdown]
# # 🧠 mnemo_ocr — Google Colab Notebook (Python 3.10.19)
# Этот ноутбук автоматически переключает Google Colab на **Python 3.10.19** и запускает проект полностью в браузере.

# %% [markdown]
# ## 🔧 Шаг 1 — Установка Python 3.10.19 (вместо 3.12)

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils python3.10-dev -y

# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --set python3 /usr/bin/python3.10

# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3

import sys
print('Python version now:', sys.version)

# %% [markdown]
# ## 📦 Шаг 2 — Установка PaddleOCR и зависимостей

# %%
# !pip install paddlepaddle==2.6.1
# !pip install paddleocr
# !pip install opencv-python-headless pandas numpy python-docx pytesseract pyyaml tqdm

# %% [markdown]
# ## 📁 Шаг 3 — Клонирование проекта mnemo_ocr

# %%
# !git clone https://github.com/bianconeri91/mnemo_ocr.git
# %cd mnemo_ocr

# %% [markdown]
# ## 🔌 Шаг 4 — Импорты и запуск OCR

# %%
from google.colab import files
import cv2
import numpy as np

from src.pipeline import extract_text
from src.ocr_utils import ocr_sensors

print('Импорты выполнены успешно 🚀')

# %% [markdown]
# ## 📤 Шаг 5 — Загрузка и распознавание изображений

# %%
uploaded = files.upload()

for fname, data in uploaded.items():
    print(f"\n📄 Обработка файла: {fname}")

    arr = np.frombuffer(data, np.uint8)
    img = cv2.imdecode(arr, cv2.IMREAD_COLOR)

    if img is None:
        print('❌ Файл не распознан как изображение.')
        continue

    color_ranges = {}
    title, sensors = extract_text(img, color_ranges)

    print('\n🏷 TITLE:', title)
    print('🧩 SENSORS:')
    for s in sensors:
        print(s)
